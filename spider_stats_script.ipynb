# %%
# import packages
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# set project name (used later in naming plots)
project_name = 'rtsb22'

# %%
# set gid to the sheet numer (found in url), change 'edit#'' to 'export?' and add 'format=csv'

# rtsb22 link 
gid = 232218977
url=f"https://docs.google.com/spreadsheets/d/1HyxulsjlOkI5Ike5KlcrEgik5Y6_XY_wVcKP6Y-eMpM/export?gid={gid}&format=csv"

# eb22 link
# gid = 0
# url=f"https://docs.google.com/spreadsheets/d/1T8-U-IXsGbO6OnRTUs29YnmREf5fuK3Ek7YTzaepXiU/export?gid={gid}&format=csv"

df = pd.read_csv(url)

df.head()
# Out:
#      etiketa metoda      Druzina        Rod           Vrsta  female  male  \
# 0  RTSB22-01  ročno  Linyphiidae    Agyneta             sp.     NaN   1.0
# 1  RTSB22-01  ročno  Linyphiidae    Agyneta      fuscipalpa     1.0   NaN
# 2  RTSB22-01  ročno    Araneidae    Araneus  cf. diadematus     NaN   NaN
# 3  RTSB22-01  ročno   Dictynidae  Brigittea          civica     2.0   1.0
# 4  RTSB22-01  ročno  Clubionidae   Clubiona             sp.     NaN   NaN
#
#     SA  juv Opombe         Kozarec Koordinate  NZS/ RF - rarely found  \
# 0  NaN  NaN  ckeck         probl.         NaN                     NaN
# 1  NaN  NaN    NaN  RTSB22 skatla1        A01                     NaN
# 2  NaN  1.0    NaN             NaN        NaN                     NaN
# 3  NaN  NaN    NaN  RTSB22 skatla1        A02                     NaN
# 4  NaN  1.0    NaN             NaN        NaN                     NaN
#
#    Koordinate v škatli
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df.dtypes
# Out:
# etiketa                    object
# metoda                     object
# Druzina                    object
# Rod                        object
# Vrsta                      object
# female                    float64
# male                      float64
# SA                         object
# juv                       float64
# Opombe                     object
# Kozarec                    object
# Koordinate                 object
# NZS/ RF - rarely found    float64
# Koordinate v škatli       float64
# dtype: object

# %%
# change column types
df.female = df.female.astype("float32")
df.male = df.male.astype("float32")
df.Druzina = df.Druzina.astype("string")
df.Rod = df.Rod.astype("string")
df.Vrsta = df.Vrsta.astype("string")

# %%
# strip whitespaces
df.Druzina = df.Druzina.str.strip()
df.Rod = df.Rod.str.strip()
df.Vrsta = df.Vrsta.str.strip()

# %%
# check typos in Family
df.Druzina.drop_duplicates().sort_values().tolist()
# Out:
# ['Agelenidae',
#  'Araneidae',
#  'Atypidae',
#  'Cheirachantiidae',
#  'Clubionidae',
#  'Dictynidae',
#  'Gnaphosidae',
#  'Linyphiidae',
#  'Lycosidae',
#  'Mimetidae',
#  'Miturgidae',
#  'Oxyopidae',
#  'Philodromidae',
#  'Pholcidae',
#  'Phrurolithidae',
#  'Pisauridae',
#  'Salticidae',
#  'Segestriidae',
#  'Tetragnathidae',
#  'Theridiidae',
#  'Thomisidae',
#  'Uloboridae',
#  'Zodariidae']

# %%
# check typos in Genus
df.Rod.drop_duplicates().sort_values().tolist()
# Out:
# ['Agelena',
#  'Agyneta',
#  'Allagelena',
#  'Araneus',
#  'Arctosa',
#  'Argiope',
#  'Attulus',
#  'Atypus',
#  'Ballus',
#  'Bathyphantes',
#  'Brigittea',
#  'Cheiracanthium',
#  'Clubiona',
#  'Diplostyla',
#  'Dolomedes',
#  'Enoplognatha',
#  'Erigone',
#  'Ero',
#  'Euryopis',
#  'Evarcha',
#  'Floronia',
#  'Frontinellina',
#  'Gibbaranea',
#  'Heliophanus',
#  'Hogna',
#  'Holocnemus',
#  'Hylyphantes',
#  'Hypsosinga',
#  'Hyptiotes',
#  'Larinioides',
#  'Leviellus',
#  'Linyphia',
#  'Mangora',
#  'Marpissa',
#  'Mendoza',
#  'Mermesus',
#  'Meta',
#  'Metellina',
#  'Microneta',
#  'Misumena',
#  'Neon',
#  'Neriene',
#  'Nuctenea',
#  'Oxyopes',
#  'Ozyptila',
#  'Palliduphantes',
#  'Panamomops',
#  'Parasteatoda',
#  'Pardosa',
#  'Philodromus',
#  'Pholcus',
#  'Phrurolithus',
#  'Phylloneta',
#  'Pirata',
#  'Piratula',
#  'Pisaura',
#  'Porrhomma',
#  'Scotophaeus',
#  'Segestria',
#  'Steatoda',
#  'Synema',
#  'Tegenaria',
#  'Tenuiphantes',
#  'Tetragnatha',
#  'Theridion',
#  'Tibellus',
#  'Tmarus',
#  'Trochosa',
#  'Walckenaria',
#  'Xerolycosa',
#  'Xysticus',
#  'Zelotes',
#  'Zodarion',
#  'Zora',
#  'Zygiella',
#  <NA>]

# %%
# check typos in Species
df.Vrsta.drop_duplicates().sort_values().tolist()
# Out:
# ['acalypha',
#  'agrestis',
#  'alticeps',
#  'alutacius',
#  'amentata',
#  'angulatus',
#  'aphana',
#  'arcuata',
#  'bavarica',
#  'bipunctata',
#  'bruennichi',
#  'bucculenta',
#  'canestrinii',
#  'cf. bipunctata',
#  'cf. diadematus',
#  'cf. falcata',
#  'cf. globosum',
#  'cf. gracilens',
#  'cf. lugubris',
#  'cf. marmoreus',
#  'cf. menardi',
#  'cf. mirabilis',
#  'cf. proxima / tenuipes',
#  'cf. quadratus',
#  'cf. quinqueguttata',
#  'cf. radiata',
#  'cf. rupicola',
#  'cf. tenuipes',
#  'cf. triangulosa',
#  'cf. umbratica',
#  'cf. vatia',
#  'chalybeius',
#  'civica',
#  'clathrata',
#  'concolor',
#  'cornutus',
#  'dentipalpis',
#  'diadematus',
#  'extensa',
#  'falcata',
#  'festivus',
#  'flavipes',
#  'flavomaculata',
#  'fuscipalpa',
#  'globosum',
#  'gracilens',
#  'gracilis',
#  'heri',
#  'impressa',
#  'labyrinthica',
#  'latitans',
#  'leopardus',
#  'lutescens',
#  'marmoreus',
#  'mengei',
#  'merianae',
#  'microphthalmum',
#  'mirabilis',
#  'montana',
#  'muscosa',
#  'nemoralis',
#  'nigrinus',
#  'nigrita',
#  'nigritus',
#  'opilionides',
#  'opilionoides',
#  'ovata',
#  'phalangioides',
#  'phragmitis',
#  'pinastri',
#  'piraticus',
#  'pluchei',
#  'praticola',
#  'prativaga',
#  'pygmaea',
#  'radiata',
#  'reticulatus',
#  'rubidum',
#  'ruricola',
#  'sclopetarius',
#  'scutulatus',
#  'segmentata',
#  'sp.',
#  'sp.1',
#  'stagnatilis',
#  'stroemi',
#  'suspicax',
#  'tenebricola',
#  'tepidariorum',
#  'terricola',
#  'thorelli',
#  'triangularis',
#  'triangulosa',
#  'trilobatus',
#  'umbratica',
#  'vatia',
#  'viaria',
#  <NA>]

# %%
# define function for cleaning dataframes
def clean_wrt_species(df):
    df["Vrsta"] = df["Vrsta"].fillna("sp.")
    species_filter = "not Vrsta.str.startswith('sp.') and not Vrsta.str.startswith('cf.')"
    df.query(species_filter, inplace=True)
    return df

# %%
# define function for counting no. of unique family, genus and species
def spider_stats(df):
    family_no = df.Druzina.nunique() 
    genus_no = df.Rod.nunique()    
    species_no = df[["Rod", "Vrsta"]].drop_duplicates().shape[0]
    print(f'{family_no} družin, {genus_no} rodov, {species_no} vrst')

# %%
# summarise the stats
clean_df = clean_wrt_species(df)
spider_stats(clean_df)
# Out:
# 17 družin, 57 rodov, 78 vrst

# %%
# define function for making etiquette for final reports
def make_etiquette(df):
    
    results = []
    for _, row in df.iterrows():    
        gender_elements = []
        if not np.isnan(row.female):
            gender_elements.append(f"{int(row.female)}F")

        if not np.isnan(row.male):
            gender_elements.append(f"{int(row.male)}M")

        results.append(f'{row.etiketa} ({", ".join(gender_elements)})')
    return ", ".join(results)


ser = clean_df.groupby(["Druzina", "Rod", "Vrsta"]).apply(make_etiquette)
ser.name = 'lokalitete'
ndf = ser.reset_index()

ndf
# Out:
#         Druzina         Rod         Vrsta  \
# 0    Agelenidae     Agelena  labyrinthica
# 1    Agelenidae  Allagelena     gracilens
# 2     Araneidae     Araneus     angulatus
# 3     Araneidae     Araneus    diadematus
# 4     Araneidae     Araneus     marmoreus
# ..          ...         ...           ...
# 73  Theridiidae   Theridion      pinastri
# 74   Thomisidae    Misumena         vatia
# 75   Thomisidae    Ozyptila     praticola
# 76   Thomisidae      Synema      globosum
# 77   Zodariidae    Zodarion       rubidum
#
#                                            lokalitete
# 0   RTSB22-02 (2F), RTSB22-12 (1F), RTSB22-13 (1F)...
# 1      RTSB22-02 (2M), RTSB22-16 (1F), RTSB22-21 (1M)
# 2                                      RTSB22-21 (1F)
# 3                                      RTSB22-28 (1M)
# 4                      RTSB22-02 (1F), RTSB22-15 (1F)
# ..                                                ...
# 73                                     RTSB22-01 (1F)
# 74  RTSB22-02 (2M), RTSB22-07 (4M), RTSB22-10 (1M)...
# 75                                     RTSB22-18 (1F)
# 76                                     RTSB22-07 (1F)
# 77  RTSB22-01 (1F, 2M), RTSB22-07 (1F), RTSB22-33 ...
#
# [78 rows x 4 columns]

# %%
# check for no M,F content
mask = ["()" in lok for lok in ndf.lokalitete]
ndf.loc[mask]
# Out:
# Empty DataFrame
# Columns: [Druzina, Rod, Vrsta, lokalitete]
# Index: []

# %%
# setup for error checkup
rv_vals = [" ".join(x) for x in clean_df[["Rod", "Vrsta"]].drop_duplicates().values]
drv_vals = [" ".join(x[1:]) for x in clean_df[["Druzina", "Rod", "Vrsta"]].drop_duplicates().values]
v1, c1 = np.unique(rv_vals, return_counts=True)
v2, c2 = np.unique(drv_vals, return_counts=True)

# %%
# compare the two, to check for human error (wrong family)
mask = (clean_df.Rod + " " + clean_df.Vrsta).isin(v1[np.where(c1 != c2)[0]])
clean_df.loc[mask][["Druzina", "Rod", "Vrsta"]].value_counts()
# Out:
# Series([], dtype: int64)

# %%
ndf["Vrsta1"] = ndf["Rod"] + ' ' + ndf["Vrsta"]
ndf = ndf.drop(['Rod', 'Vrsta'], axis=1)
ndf = ndf[['Druzina', 'Vrsta1', 'lokalitete']]
ndf
# Out:
#         Druzina                Vrsta1  \
# 0    Agelenidae  Agelena labyrinthica
# 1    Agelenidae  Allagelena gracilens
# 2     Araneidae     Araneus angulatus
# 3     Araneidae    Araneus diadematus
# 4     Araneidae     Araneus marmoreus
# ..          ...                   ...
# 73  Theridiidae    Theridion pinastri
# 74   Thomisidae        Misumena vatia
# 75   Thomisidae    Ozyptila praticola
# 76   Thomisidae       Synema globosum
# 77   Zodariidae      Zodarion rubidum
#
#                                            lokalitete
# 0   RTSB22-02 (2F), RTSB22-12 (1F), RTSB22-13 (1F)...
# 1      RTSB22-02 (2M), RTSB22-16 (1F), RTSB22-21 (1M)
# 2                                      RTSB22-21 (1F)
# 3                                      RTSB22-28 (1M)
# 4                      RTSB22-02 (1F), RTSB22-15 (1F)
# ..                                                ...
# 73                                     RTSB22-01 (1F)
# 74  RTSB22-02 (2M), RTSB22-07 (4M), RTSB22-10 (1M)...
# 75                                     RTSB22-18 (1F)
# 76                                     RTSB22-07 (1F)
# 77  RTSB22-01 (1F, 2M), RTSB22-07 (1F), RTSB22-33 ...
#
# [78 rows x 3 columns]

# %%
# load csv, import in GSheets file
ndf.to_csv(f"{project_name}.csv", index=False)

# %%
data = df.etiketa.value_counts()
new_index = np.argsort(data.index)

fig = plt.figure(figsize=(10,5))

plt.bar(data.index[new_index], data.values[new_index])
plt.xticks(rotation=90);

plt.xlabel('Oznaka lokalitete')
plt.ylabel('Število vrst')

#savefig before plt.show
plt.savefig(f'./{project_name}_species_per_location_hist_v2.png', bbox_inches = 'tight')
plt.show()

# %%
# set size before plt.hist
fig = plt.figure(figsize=(10,5))

_, edges, _ = plt.hist(data=df, x='etiketa',edgecolor='black',color='steelblue', histtype='bar', bins=np.arange(df.etiketa.nunique()+1))
plt.xticks(
    ticks=edges[:-1]+0.5, 
    labels=df.etiketa.unique()[::-1], 
    rotation=90
)

# plt.xticks(rotation=90)
plt.xlabel('Oznaka lokalitete')
plt.ylabel('Število vrst')

#savefig before plt.show
plt.savefig(f'./{project_name}_species_per_location_hist.png', bbox_inches = 'tight')
plt.show()
